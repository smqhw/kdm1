# %% [markdown]
# <a href="https://colab.research.google.com/github/smqhw/kdm1/blob/main/icp8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install spacy
# !pip install textacy
# Out:
# ...
#      |████████████████████████████████| 184kB 8.1MB/s
# ...
#      |████████████████████████████████| 1.9MB 9.5MB/s
# ...
#      |████████████████████████████████| 92kB 8.7MB/s
# ...
#      |████████████████████████████████| 481kB 38.9MB/s
# ...
#   Created wheel for cytoolz: filename=cytoolz-0.11.0-cp37-cp37m-linux_x86_64.whl size=1223254 sha256=39bfd6191f9f42808a6fd7028ae6c317a5e17a0507627eddab131ead10c6355d
#   Stored in directory: /root/.cache/pip/wheels/a1/32/3c/9c9926b510647cacdde744b2c7acdf1ccd5896fbb7f8d5df0c
# Successfully built cytoolz
# ...

# %%
import spacy
import textacy

f = open('/content/abs3.txt', 'r')
nlp = spacy.load("en_core_web_sm")
doc = nlp(f.read())
f.close()

for token in doc:
    print(token.text, token.pos_, token.dep_)

tuples_list = []
tuples = textacy.extract.subject_verb_object_triples(doc)
tuples_to_list = list(tuples)
if tuples_to_list != []:
    tuples_list.append(tuples_to_list)

print(tuples_list)
# Out:
# " PUNCT punct
# You PRON nmod
# guys NOUN nsubj
# have AUX aux
# only ADV advmod
# been AUX ccomp
# in ADP prep
# office NOUN pobj
# for ADP prep
# a DET det
# month NOUN pobj
# , PUNCT punct
# right ADJ ROOT
# ? PUNCT punct
# Are AUX aux
# you PRON nsubj
# telling VERB ROOT
# me PRON dobj
# that SCONJ dobj
# in ADP prep
# the DET det
# last ADJ amod
# four NUM nummod
# weeks NOUN pobj
# these DET det
# 18 NUM nummod
# companies NOUN intj
# all DET nsubj
# of ADP prep
# the DET det
# sudden ADV pobj
# decided VERB relcl
# to PART aux
# say VERB xcomp
# , PUNCT punct
# ‘ PUNCT punct
# Oh INTJ intj
# my DET intj
# God INTJ intj
# ! PUNCT punct
# We PRON nsubj
# better ADV advmod
# not PART neg
# doing VERB ccomp
# anything PRON dobj
# with ADP prep
# Nord PROPN compound
# Stream PROPN pobj
# 2 NUM nummod
# , PUNCT punct
# " PUNCT punct
# Lee PROPN nsubj
# said VERB ROOT
# . PUNCT punct
# " PUNCT punct
# You PRON nmod
# guys NOUN nsubj
# are AUX aux
# taking VERB ROOT
# ...
